# %% [raw]
# ---
# layout: post
# title: Homework Blog
# permalink: /homeworkblog
# ---

# %% [markdown]
# ## Homework Links
#
# Iterations:
#
# [Link to Nested Conditionals](https://sadafm289.github.io/portfolio/js/nested-conditionals)
#
# Arrays: I taught this lesson!
#
# Mathematical Expressions:
#
# JSON:
#
# Strings:
#
# Data Abstractions:
