# %% [raw]
# ---
# layout: post
# title: Homework Blog
# permalink: /homeworkblog
# ---

# %% [markdown]
# ## Homework Links
#
# Iterations:
#
# Nested Conditionals:
#
# Arrays:
#
# Mathematical Expressions:
