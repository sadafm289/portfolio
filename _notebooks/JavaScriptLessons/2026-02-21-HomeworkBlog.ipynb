# %% [raw]
# ---
# layout: post
# title: Homework Blog
# permalink: /homeworkblog
# ---

# %% [markdown]
# ## Homework Links
#
# [Link to Iterations](https://sadafm289.github.io/portfolio/js/iterations)
# - This homework taught me how to combine iterations and loops in one to code amazing things!
#
# [Link to Nested Conditionals](https://sadafm289.github.io/portfolio/js/nested-conditionals)
# - I learned from this homework how to use nested conditionals with numbers and code a complex program.
#
# Arrays: I taught this lesson!
#
# [Link to Mathematical Expressions](https://sadafm289.github.io/portfolio/js/math)
# - This homework taught me how to use mathematical expressions and code amazing things like a mini calculator and check the divisibility of a number.
#
# [Link to JSON](https://sadafm289.github.io/portfolio/js/json)
# - I learned from this homework how to make a mini resume using JSON.
#
# [Link to Strings](https://sadafm289.github.io/portfolio/js/strings)
# - After this homework, I learned how to use string interpolation in coding. Which is an advancement from coding simple strings.
#
# [Link to Data Abstractions](https://sadafm289.github.io/portfolio/js/data-abstraction/)
# - This homework taught me how to tell unnecessary lines of code to improve organization. I also learned how to code a subclass.
#
# [Link to Classes and Methods](https://sadafm289.github.io/portfolio/js/classes)
# - This homework taught me how to make a basic class combined with 2 methods. I chose to create a class called dog.
